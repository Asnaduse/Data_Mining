# %%
import pandas as pd
main_file = pd.read_excel("financial_sample.xlsx")
# Insert the new column at index 0 (before all other columns)
main_file.insert(0, 'id', range(1, len(main_file) + 1))
main_file.head()
# Out:
#    id     Segment  Country    Product Discount Band  Units Sold  \
# 0   1  Government   Canada  Carretera           NaN      1618.5
# 1   2  Government  Germany  Carretera           NaN      1321.0
# 2   3   Midmarket   France  Carretera           NaN      2178.0
# 3   4   Midmarket  Germany  Carretera           NaN       888.0
# 4   5   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
main_file.rename(columns = {"Product":"product_name","Country":"city", "Discount Band":"category", "Units Sold":"price", "Sale Price":"quantity", "Month Name":"month", "Date":"date", "Year":"year", "Segment":"customer_name","Gross Sales":"total_sales"}, inplace = True)

# %%
main_file.head(2)
# Out:
#    id customer_name     city product_name category   price  \
# 0   1    Government   Canada    Carretera      NaN  1618.5
# 1   2    Government  Germany    Carretera      NaN  1321.0
#
#    Manufacturing Price  quantity  total_sales  Discounts    Sales     COGS  \
# 0                    3        20      32370.0        0.0  32370.0  16185.0
# 1                    3        20      26420.0        0.0  26420.0  13210.0
#
#     Profit       date  Month Number    month  year
# 0  16185.0 2014-01-01             1  January  2014
# 1  13210.0 2014-01-01             1  January  2014

# %%
product = main_file[['id','product_name', 'category']]
product.to_csv("product_data.csv", index=False)
productnew = pd.read_csv("product_data.csv")
productnew.rename(columns = {"id": "product_id"},inplace = True)
productnew.head()
# Out:
#    product_id product_name category
# 0           1    Carretera      NaN
# 1           2    Carretera      NaN
# 2           3    Carretera      NaN
# 3           4    Carretera      NaN
# 4           5    Carretera      NaN

# %%
customer = main_file[['id','customer_name','city']]
customer.to_csv("customer_data.csv", index=False)
customernew = pd.read_csv("customer_data.csv")
customernew.rename(columns = {'id': 'customer_id'}, inplace = True)
customernew.head()
# Out:
#    customer_id customer_name     city
# 0            1    Government   Canada
# 1            2    Government  Germany
# 2            3     Midmarket   France
# 3            4     Midmarket  Germany
# 4            5     Midmarket   Mexico

# %%
customerr=customernew[['customer_id']]
productt=productnew[['product_id']]
datee=datenew[['date_id']]
saless=salesnew[['quantity','price','total_sales']]
new=pd.concat([customerr,productt,datee,saless],axis=1,join='inner')
new
# Out:
#      customer_id  product_id  date_id  quantity   price  total_sales
# 0              1           1        1        20  1618.5      32370.0
# 1              2           2        2        20  1321.0      26420.0
# 2              3           3        3        15  2178.0      32670.0
# 3              4           4        4        15   888.0      13320.0
# 4              5           5        5        15  2470.0      37050.0
# ..           ...         ...      ...       ...     ...          ...
# 695          696         696      696       300  2475.0     742500.0
# 696          697         697      697       300   546.0     163800.0
# 697          698         698      698         7  1368.0       9576.0
# 698          699         699      699         7   723.0       5061.0
# 699          700         700      700        12  1806.0      21672.0
#
# [700 rows x 6 columns]

# %%
date = main_file[['id','date','month','year']]
date.to_csv("date_data.csv", index=False)
datenew = pd.read_csv("date_data.csv")
datenew.rename(columns = {'id':'date_id'}, inplace = True)
datenew.head()
# Out:
#    date_id        date    month  year
# 0        1  2014-01-01  January  2014
# 1        2  2014-01-01  January  2014
# 2        3  2014-06-01     June  2014
# 3        4  2014-06-01     June  2014
# 4        5  2014-06-01     June  2014

# %%
sales = main_file[['id','quantity','price','total_sales']]
sales.to_csv("sales_data.csv", index=False)
salesnew = pd.read_csv("sales_data.csv")
salesnew.rename(columns = {'id':'transaction_id'}, inplace = True)
salesnew.head()
# Out:
#    transaction_id  quantity   price  total_sales
# 0               1        20  1618.5      32370.0
# 1               2        20  1321.0      26420.0
# 2               3        15  2178.0      32670.0
# 3               4        15   888.0      13320.0
# 4               5        15  2470.0      37050.0

# %%
# !pip install mysql-connector-python pandas sqlalchemy

# %%
import mysql.connector as mc
from sqlalchemy import create_engine

# %%
username = "root"
password = ""
host = "localhost"
database = "finance"
db_url = f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
engine = create_engine(db_url)

# %%
productnew = pd.DataFrame(productnew)
datenew = pd.DataFrame(datenew)
customernew = pd.DataFrame(customernew)
new = pd.DataFrame(new)

# %%
# productnew.to_sql("product_data", con=engine, if_exists="append", index=False)
# datenew.to_sql("date_data", con=engine, if_exists="append", index=False)
# customernew.to_sql("customer_data", con=engine, if_exists="append", index=False)
new.to_sql("sale_data", con=engine, if_exists="append", index=False)
# Out:
# 700

# %%
print(pd.read_sql('SELECT * FROM sale_data LIMIT 10',engine))
# Out:
#    customer_id  product_id  date_id  quantity   price  total_sales
# 0            1           1        1        20  1618.5      32370.0
# 1            2           2        2        20  1321.0      26420.0
# 2            3           3        3        15  2178.0      32670.0
# 3            4           4        4        15   888.0      13320.0
# 4            5           5        5        15  2470.0      37050.0
# 5            6           6        6       350  1513.0     529550.0
# 6            7           7        7        15   921.0      13815.0
# 7            8           8        8        12  2518.0      30216.0
# 8            9           9        9        20  1899.0      37980.0
# 9           10          10       10        12  1545.0      18540.0
